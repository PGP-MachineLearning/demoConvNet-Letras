# %% [markdown]
# # Programa auxiliar para seleccionar al azar las imágenes para 'Predict'

# %% [markdown]
# 0) Indicar la cantidad de imágenes para seleccionar:

# %%
cantImagenesSelecc = 10

# %% [markdown]
# 1) Cargar librerías:

# %%
import os
import os.path
import numpy as np
import shutil

print ("Librerías cargadas.")
# Out:
# Librerías cargadas.

# %% [markdown]
# 2) Montar el Drive:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = 'gdrive/My Drive/IA - no listo/demoConvNet-Letras'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# 3) Levantar y procesa la lista de imágenes a procesar:

# %%
# variables auxiliares
all_images_array = []
auxiPath = path + "/TodasLetras"
all_dirs = os.listdir(auxiPath)

# crea los directorios, si es necesario
pathPredict = path +'/Predict'
if not os.path.isdir(pathPredict):
  os.makedirs(pathPredict)

# procesa cada directorio
allFileNames = []
for each_dir in all_dirs:
  # levanta la lista de imágenes de cada letra
  auxFileNames = os.listdir("".join([auxiPath, "/", each_dir]))

  # le agrega el path completo  
  for fn in auxFileNames:
    allFileNames.append( auxiPath + '/' + each_dir + '/' + fn )


# desordena y toma sólo una pocas imágenes
np.random.shuffle(allFileNames)
predict_FileNames, no_FileNames = np.split(np.array(allFileNames), [cantImagenesSelecc])

print('Total: ', len(allFileNames))
print('Predict: ', len(predict_FileNames))
print('No Predict: ', len(no_FileNames))

# copia las imágenes seleccionadas
cant = 0
for name in predict_FileNames:
    shutil.copy(name, pathPredict)
    print(name, "copiada")
    cant = cant + 1

print(cant, " imágenes copiadas a ", pathPredict)
# Out:
# Total:  36585
# Predict:  10
# No Predict:  36575
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/4/img005-00012.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/3/img004-00495.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/K/img021-00855.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/R/img028-00569.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/D/img014-00901.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/F/img016-00680.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/R/img028-00058.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/W/img033-00135.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/Z/img036-00521.png copiada
# gdrive/My Drive/IA - no listo/demoConvNet-Letras/TodasLetras/Q/img027-00360.png copiada
# ...
